# %%
# Задание 1

from matplotlib import pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

plt.plot(x, y)
plt.title("Графики функций")
plt.xlabel('x')
plt.ylabel('y')
plt.grid(color="lightgrey")
plt.show()

plt.scatter(x, y)
plt.title("Диаграмма рассеяния")
plt.xlabel('x')
plt.ylabel('y')
plt.grid(color="lightgrey")
plt.show()

# %%
# Задание 2

import numpy as np
import pandas as pd

t = np.linspace(0, 10, 51)
f = np.cos(t)
plt.plot(t, f, color="green")
plt.title("График f(t)")
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.grid(color="lightgrey")
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.show()

# %%
# Задание 3

import numpy as np

x = np.linspace(-3, 1, 51)
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()

fig.set_size_inches(8, 6)
fig.subplots_adjust(wspace=0.3, hspace=0.3)

ax1.plot(x, y1)
ax1.set_title("График y1")
ax1.set_xlim([-5, 5])
ax2.plot(x, y2)
ax2.set_title("График y2")
ax3.plot(x, y3)
ax3.set_title("График y3")
ax4.plot(x, y4)
ax4.set_title("График y4")
# Out:
# Text(0.5, 1.0, 'График y4')

# %%
# Задача 4
# !pip install fsspec

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('fivethirtyeight')

# df = pd.read_csv('creditcard.csv', index_col=0)
with open('creditcard.csv', 'rb') as f:
  df = pd.read_csv(f)

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
# 5   2.0 -0.425966  0.960523  1.141109  ...  0.253844  0.081080    3.67    0.0
# 6   4.0  1.229658  0.141004  0.045371  ...  0.034507  0.005168    4.99    0.0
# 7   7.0 -0.644269  1.417964  1.074380  ... -1.206921 -1.085339   40.80    0.0
# 8   7.0 -0.894286  0.286157 -0.113192  ...  0.011747  0.142404   93.20    0.0
# 9   9.0 -0.338262  1.119593  1.044367  ...  0.246219  0.083076    3.68    0.0
#
# [10 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160580 entries, 0 to 160579
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    160580 non-null  float64
#  1   V1      160580 non-null  float64
#  2   V2      160580 non-null  float64
#  3   V3      160580 non-null  float64
#  4   V4      160580 non-null  float64
#  5   V5      160580 non-null  float64
#  6   V6      160580 non-null  float64
#  7   V7      160580 non-null  float64
#  8   V8      160580 non-null  float64
#  9   V9      160580 non-null  float64
#  10  V10     160579 non-null  float64
#  11  V11     160579 non-null  float64
#  12  V12     160579 non-null  float64
#  13  V13     160579 non-null  float64
#  14  V14     160579 non-null  float64
#  15  V15     160579 non-null  float64
#  16  V16     160579 non-null  float64
#  17  V17     160579 non-null  float64
#  18  V18     160579 non-null  float64
#  19  V19     160579 non-null  float64
# ...

# %%
df['Class'].value_counts()
# Out:
# 0.0    160223
# 1.0       356
# Name: Class, dtype: int64

# %%
ax1, ax2 = df['Class'].value_counts()

# %%
index = df['Class'].unique()
index
# Out:
# array([ 0.,  1., nan])

# %%
index = df['Class'].unique()
index = index[:2]
values = [ax1, ax2]

cards_info = pd.Series(values, index)
cards_info.plot(kind='bar')

plt.show()

# %%
index = df['Class'].unique()
index = index[:2]
values = [ax1, ax2]

cards_info = pd.Series(values, index)
cards_info.plot(kind='bar')
plt.yscale(value="log")

plt.show()

# %%
tmp1 = df[df['Class'] == 1]
tmp1
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 541        406.0 -2.312227  1.951992  ... -0.143276    0.00    1.0
# 623        472.0 -3.043541 -3.157307  ...  0.035764  529.00    1.0
# 4920      4462.0 -2.303350  1.759247  ... -0.153029  239.93    1.0
# 6108      6986.0 -4.397974  1.358367  ...  0.849573   59.00    1.0
# 6329      7519.0  1.234235  3.019740  ...  0.146793    1.00    1.0
# ...          ...       ...       ...  ...       ...     ...    ...
# 156990  109298.0 -1.000611  3.346850  ...  0.326952  186.13    1.0
# 157585  110087.0  1.934946  0.650678  ... -0.051082    1.00    1.0
# 157868  110547.0 -1.532810  2.232752  ... -0.106667    0.76    1.0
# 157871  110552.0 -2.450367  2.107729  ... -0.115471   80.22    1.0
# 157918  110617.0 -1.101035 -1.674928  ... -0.832855  635.10    1.0
#
# [356 rows x 31 columns]

# %%
tmp2 = df[df['Class'] == 0]
tmp2
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 0            0.0 -1.359807 -0.072781  ... -0.021053  149.62    0.0
# 1            0.0  1.191857  0.266151  ...  0.014724    2.69    0.0
# 2            1.0 -1.358354 -1.340163  ... -0.059752  378.66    0.0
# 3            1.0 -0.966272 -0.185226  ...  0.061458  123.50    0.0
# 4            2.0 -1.158233  0.877737  ...  0.215153   69.99    0.0
# ...          ...       ...       ...  ...       ...     ...    ...
# 160574  113469.0  1.977569 -1.266205  ... -0.037054   89.99    0.0
# 160575  113471.0  2.055797 -0.326668  ... -0.060282    1.00    0.0
# 160576  113471.0  2.027248 -0.123314  ... -0.036266   12.14    0.0
# 160577  113471.0 -0.904898  1.131663  ...  0.086706   12.91    0.0
# 160578  113472.0  1.997105  0.449015  ... -0.019878   35.95    0.0
#
# [160223 rows x 31 columns]

# %%
cheat = tmp1['V1'].values
cheat
# Out:
# array([-2.31222654e+00, -3.04354062e+00, -2.30334957e+00, -4.39797444e+00,
#         1.23423505e+00,  8.43036490e-03,  2.67792264e-02,  3.29594333e-01,
#         3.16459000e-01,  7.25645740e-01,  7.02709900e-01,  1.02387387e+00,
#        -1.58550537e+00, -1.78322884e+00,  8.57321004e-01, -1.81328048e+00,
#        -2.51470960e-01,  3.14596590e-01,  4.47395553e-01, -2.16992898e+00,
#        -1.86375555e+00, -4.61721720e+00, -2.66180217e+00, -2.53585212e+00,
#        -3.49910754e+00, -2.12548983e+00,  3.78274504e-01, -1.42662331e+00,
#        -3.89119195e+00,  9.19136507e-01, -4.69679522e+00, -4.72771266e+00,
#        -4.06400474e+00, -2.58961720e+00, -2.88004235e+00, -5.45436178e+00,
#        -4.15301450e+00, -4.71052878e+00, -4.64189285e+00,  1.08837494e+00,
#         1.18978436e+00, -4.69326705e-01, -5.26805322e+00, -5.18787811e+00,
#        -1.22240206e+01, -1.44744375e+01, -1.23396032e+01, -1.53988450e+01,
# ...

# %%
usual = tmp2['V1'].values
usual
# Out:
# array([-1.35980713,  1.19185711, -1.35835406, ...,  2.02724843,
#        -0.90489829,  1.99710472])

# %%
# %config InlineBackend.figure_format = 'svg'
hist_info = plt.hist(cheat, bins=20, color="grey", ec="white", alpha=0.5, density=True)
hist_info2 = plt.hist(usual, bins=20, color="red", ec="white", alpha=0.5, density=True)
plt.title("Гистограммы транзакций")
plt.xlabel("V1")
plt.legend(labels=["Class 0", "Class 1"], loc="upper left")
plt.axis([-32, 0, 0, 0.22])
plt.show()
